# %% [markdown]
# <a href="https://colab.research.google.com/github/mrAlimovich/computer_vision1/blob/main/cv_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow
image = cv2.imread("/content/cat_image.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
print("SHAPE:", image.shape)
# 168 => height
# 300 => width
# 3 => color channels (BGR) => Blue, Green, Red
print("HEIGHT:", image.shape[0])
print("WIDTH:", image.shape[1])
print("CHANNELS:", image.shape[2])
# Out:
# SHAPE: (168, 300, 3)
# HEIGHT: 168
# WIDTH: 300
# CHANNELS: 3

# %%
(b, g, r) = image[100,50]
print("Blue:", b, "Green:", g, "Red:",r)
# Out:
# Blue: 55 Green: 180 Red: 134

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
resized = cv2.resize(gray,[300, 300])
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %%
cropped = gray[50:280, 150:350]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=L size=150x118>

# %%
rotated = cv2.rotate(gray, cv2.ROTATE_90_COUNTERCLOCKWISE)
cv2_imshow(rotated)
# Out:
# <PIL.Image.Image image mode=L size=168x300>

# %%
flipped = cv2.flip(gray, 1)
cv2_imshow(flipped)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
cv2.imwrite("cropped_cat.jpg", cropped)
# Out:
# True

# %%
cropped_cat = cv2.imread("/content/cropped_cat.jpg")
cv2_imshow(cropped_cat)
# Out:
# <PIL.Image.Image image mode=RGB size=150x118>
